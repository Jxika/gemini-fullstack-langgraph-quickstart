# %%
from agent.graph import graph

state = graph.invoke({"messages": [{"role": "user", "content": """WEE1靶点管线调研"""}], "max_research_loops": 3, "initial_search_query_count": 3})
# Out:
# 2025-11-21 14:35:05 [INFO] agent.utils - 💬len(messages)=1,research_topic=WEE1靶点管线调研
# 时间November 21, 2025
# 2025-11-21 14:35:12 [INFO] agent.graph - 🔧continue_to_web_research|📄任务 0: search_query='WEE1 inhibitor clinical trials pipeline 2024 2025'
# 2025-11-21 14:35:12 [INFO] agent.graph - 🔧continue_to_web_research|📄任务 1: search_query='WEE1 targeted therapy development status oncology'
# 2025-11-21 14:35:12 [INFO] agent.graph - 🔧continue_to_web_research|📄任务 2: search_query='WEE1靶点药物研发进展 临床试验'
# 2025-11-21 14:35:33 [INFO] agent.graph - get_tools|llm返回:我将为您搜索WEE1靶点药物研发进展和临床试验的相关信息。让我先进行一些针对性的搜索。
# 2025-11-21 14:35:33 [INFO] agent.graph - get_tools|llm返回工具:[{'name': 'web_search', 'args': {'query': 'WEE1靶点药物研发进展 临床试验 2024 2025', 'state': {'search_query': 'WEE1靶点药物研发进展 临床试验 2024 2025', 'id': '1'}}, 'id': 'call_00_kJTErgJUWga9PY5DJNhnBDkc', 'type': 'tool_call'}]
# 2025-11-21 14:35:33 [INFO] agent.graph - ----------------------------
# ...

# %%
state
# Out:
# {'messages': [HumanMessage(content='Who won the euro 2024', additional_kwargs={}, response_metadata={}, id='4b0ccc12-2e74-4a55-a85e-c512e7867c26'),
# ...

# %%
from IPython.display import Markdown

Markdown(state["messages"][-1].content)
# Out:
# Spain won the UEFA Euro 2024 tournament [youtube](https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGFcidniPKtBR-_QjSR1P1Oathq_0T9FTwfpCAWZxbXsroItHQU8zRcyOPDgMcvsWoD2fEnwYFKwanV18ep2_cyS5BlHF6-OFNsijWb-peAgsgLAVRiubekRnzMugsYtiWrhZyO3Q==) [aljazeera](https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXEk7ApC7Y41UOrTWJ40wP2rsT0VDxqhqF-WJEI-FNKW7SNpR7LoA22sRQecS8hZNeZ_-62Vh7X75RmcmZUtnAOuQunrLAsETkkSx5l75dt9ESgTRkIURwtu4Pew7hn8yFz_LY_FJXUpmRfoWP7MWrDfPHcKrOpfmKqONj6mJcASNvAfCZ0p6qK3K4PvKWye6NyBMyYxWCuJig==) [foxsports](https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHh_4hBL0Giyuw_cyfT8m7tUSnMqBqH4Lis1CtJICPJNGGLhT6PADTIoUtrj3Rl5qcKNE9T6rzOmedAER_gxJOBDrCF8pnr9lUvhYvmDJxYCJzELkE5rTap4dx6FzOIKZKm1QBp5aHXzd_LCkSTV9ag7Q1A6_t8Vjdbskch6ZG3BoIfjYDQSPgRKDNFAAwt5J07cVFV5pDQzggmM7pxwsUz4drz) [wikipedia](https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGd9ZQky3X7RQLbTs6mY1i4Pg7ppcI5H_vtxpvQPiEyD8Qw0f7hjvn3QeoOeAVcCG_pEt
# ...

# %%
state = graph.invoke({"messages": state["messages"] + [{"role": "user", "content": "How has the most titles? List the top 5"}]})

# %%
Markdown(state["messages"][-1].content)
# Out:
# Based on the number of UEFA European Championship titles won, Spain holds the record [olympics](https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHoAXOG7_3DUjYvRr_buN8IAL3xE5yQoPetZCb1KlcaMOgJEE5BeBoqQEVVkDZLDpwgTmFkPYeWS7i_D23Vd5bKzUTfc0HSLI481VbXjMD9ECeZRFZ17g3xAYLg5I0QU34RWLCRcV_zgphUsJZ0L5gXjpYz5gl8syuYAX3VkHCwh0x6Wqau4er_cZ56CoiA-3S_r2I=) [sportsadda](https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXEYq2a0benYn0vF2WrfvmqEsgwriQ08aVcDdpS1MUjBxlzaV_scV0ldVeUpwqcgVLCfxgX3oVmbUxbkFPzeHbknsAbxLFk4Iyvtxgacx54AZBnL1szGQ9cQQGOOT8f-zGZhzKWEhAIOYTsz89uAr55R546MlC31OFXiU7AGhMgLi0Ekk6wQvPJVTWs_TiaG4MHoHo0obaRhJK1iPYaAxqHKD2Zf5rTr2jmdPBPd9w==) [wikipedia](https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXG_0rXuWu0vsaIzCzaUG9Rw0L65I3o3RWhCp4gzXiHDZW3GaJXLntEQNi-O88mGf5LlE0tAkMNd_5VBNOkzIxAkbVsdkpPjwtzuY1sjv2gjtHLnvbIa8Y9jFbdS8kE3xqj95_TayzxNWpyr-XkwY9qLW4NI) [yahoo](https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXE
# ...

# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

print("Gemini key prefix:", (os.getenv("GEMINI_API_KEY") or "")[:10])

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.7,api_key=os.getenv("GEMINI_API_KEY"))

print("Sending request...")
result = llm.invoke("List three AI research breakthroughs in 2024.")
print("Response:", result)
# Out:
# Gemini key prefix: AIzaSyCPEQ
# Sending request...
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File d:\code\gemini-fullstack-langgraph-quickstart\.venv\Lib\site-packages\google\api_core\grpc_helpers.py:75, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      74 try:
# ---> 75     return callable_(*args, **kwargs)
#      76 except grpc.RpcError as exc:
#
# File d:\code\gemini-fullstack-langgraph-quickstart\.venv\Lib\site-packages\grpc\_interceptor.py:276, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     267 def __call__(
#     268     self,
#     269     request: Any,
#    (...)    274     compression: Optional[grpc.Compression] = None,
#     275 ) -> Any:
# --> 276     response, ignored_call = self._with_call(
#     277         request,
#     278         timeout=timeout,
# ...

# %%
import os
from dotenv import load_dotenv
from google import genai

# 载入 .env 文件中的 GEMINI_API_KEY
load_dotenv()

api_key = os.getenv("GEMINI_API_KEY")
print("Gemini key prefix:", (api_key or "")[:10])

# 创建 Gemini 客户端
client = genai.Client(api_key=api_key)

print("Sending request...")

# 生成模型调用（建议使用 gemini-2.0-flash 或 gemini-2.5-flash）
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="List three AI research breakthroughs in 2024."
)

print("Response:", response.text)
# Out:
# Gemini key prefix: AIzaSyCPEQ
# Sending request...
# Response: As of mid-2024, here are three significant AI research breakthroughs:
#
# 1.  **OpenAI's Sora (Text-to-Video Model):** Announced in February 2024, Sora represents a major leap in generative AI's ability to create realistic and coherent videos from text prompts. Unlike previous video generation models, Sora can produce longer, more complex scenes with multiple characters, specific motion, and accurate rendering of object physics within the generated world, significantly advancing the realism and control in video synthesis.
#
# ...

# %% [markdown]
# | 登记号 | 试验药 | 适应症 | 试验状态 | 试验分期 |
# | --- | --- | --- | --- | --- |
# | NCT06667141 | PKMYT1 抑制剂(Acrivon Therapeutics) | 晚期恶性实体瘤 | Recruiting | 临床1期 |
